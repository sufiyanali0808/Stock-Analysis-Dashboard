# %%
import pandas as pd
from urllib.parse import quote_plus
# !pip install sqlalchemy pymysql
from sqlalchemy import create_engine

df = pd.read_csv("stock_details_5_years.csv")
df.head()
# Out:
# ...
# [notice] A new release of pip is available: 24.3.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
#                         Date        Open        High         Low       Close  \
# 0  2018-11-29 00:00:00-05:00   43.829761   43.863354   42.639594   43.083508
# 1  2018-11-29 00:00:00-05:00  104.769074  105.519257  103.534595  104.636131
# 2  2018-11-29 00:00:00-05:00   54.176498   55.007500   54.099998   54.729000
# 3  2018-11-29 00:00:00-05:00   83.749496   84.499496   82.616501   83.678497
# 4  2018-11-29 00:00:00-05:00   39.692784   40.064904   38.735195   39.037853
#
#       Volume  Dividends  Stock Splits Company
# 0  167080000       0.00           0.0    AAPL
# 1   28123200       0.00           0.0    MSFT
# 2   31004000       0.00           0.0   GOOGL
# 3  132264000       0.00           0.0    AMZN
# 4   54917200       0.04           0.0    NVDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 375853 entries, 0 to 375852
# Data columns (total 9 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Date          375853 non-null  object
#  1   Open          375853 non-null  float64
#  2   High          375853 non-null  float64
#  3   Low           375852 non-null  float64
#  4   Close         375852 non-null  float64
#  5   Volume        375852 non-null  float64
#  6   Dividends     375852 non-null  float64
#  7   Stock Splits  375852 non-null  float64
#  8   Company       375852 non-null  object
# dtypes: float64(7), object(2)
# memory usage: 25.8+ MB

# %%
df.describe()
# Out:
#                 Open           High            Low          Close  \
# count  375853.000000  375853.000000  375852.000000  375852.000000
# mean      127.922001     129.524166     126.264550     127.920124
# std       247.033747     250.334582     243.720558     247.051630
# min         1.052425       1.061195       1.026114       1.034884
# 25%        36.467866      36.930000      35.998471      36.473145
# 50%        73.000000      73.869705      72.112494      72.987190
# 75%       147.330002     149.154923     145.531229     147.393925
# max      5977.609863    5982.450195    5884.060059    5959.330078
#
#              Volume      Dividends   Stock Splits
# count  3.758520e+05  375852.000000  375852.000000
# mean   5.917514e+06       0.006622       0.000302
# std    1.471040e+07       0.109846       0.037817
# min    0.000000e+00       0.000000       0.000000
# 25%    1.005200e+06       0.000000       0.000000
# 50%    2.195600e+06       0.000000       0.000000
# ...

# %%
df.isnull().sum()
# Out:
# Date            0
# Open            0
# High            0
# Low             1
# Close           1
# Volume          1
# Dividends       1
# Stock Splits    1
# Company         1
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Date            0
# Open            0
# High            0
# Low             0
# Close           0
# Volume          0
# Dividends       0
# Stock Splits    0
# Company         0
# dtype: int64

# %%
df.columns = df.columns.str.lower()
df.columns = df.columns.str.replace(' ', '_')
df.columns
# Out:
# Index(['date', 'open', 'high', 'low', 'close', 'volume', 'dividends',
#        'stock_splits', 'company'],
#       dtype='object')

# %%
# Convert the date column to datetime
df["date"] = pd.to_datetime(df["date"])

# Group by month and calculate the average closing price
monthly = (
    df.groupby(df["date"].dt.to_period("M"))["close"]
      .mean()
      .reset_index()
)

# Convert the period column to string (optional)
monthly["date"] = monthly["date"].astype(str)
# Out:
# /tmp/ipykernel_3155/269514677.py:6: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   df.groupby(df["date"].dt.to_period("M"))["close"]

# %%
username = "root"
password = quote_plus("SufiY@n.05_*_")
host = "localhost"      # e.g., "34.123.45.67" or your PC's public IP
port = 3306
database = "stock_analysis"

engine = create_engine(f"mysql+pymysql://root:{password}@localhost:3306/stock_analysis")

df.to_sql(
    "stocks",
    con=engine,
    if_exists="replace",
    index=False
)

print(f"data successfully loaded to stocks in databse '{database} .")
# Out:
# data successfully loaded to stocks in databse 'stock_analysis .
